# %%
from tau_profile_parser import TauProfileParser
from tau_callpath_parser import CallPaths
import pandas as pd
import numpy as np
import hatchet as ht
import re

# %% [markdown]
# ### Reading data with Tau profile parser

# %%
data = TauProfileParser.parse('0').interval_data()

# %%
CallPaths.to_heat_map(data, metric='Exclusive', node=0, context=0, threads=range(0, 64))
# Out:
# <div>
#
#
#             <div id="3c88a4f8-a1cb-4ffb-9dd5-d0a54310456e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3c88a4f8-a1cb-4ffb-9dd5-d0a54310456e")) {
#                     Plotly.newPlot(
#                         '3c88a4f8-a1cb-4ffb-9dd5-d0a54310456e',
#                         [{"type": "heatmap", "x": ["thrd_0", "thrd_1", "thrd_2", "thrd_3", "thrd_4", "thrd_5", "thrd_6", "thrd_7", "thrd_8", "thrd_9", "thrd_10", "thrd_11", "thrd_12", "thrd_13", "thrd_14", "thrd_15", "thrd_16", "thrd_17", "thrd_18", "thrd_19", "thrd_20", "thrd_21", "thrd_22", "thrd_23", "thrd_24", "thrd_25", "thrd_26", "thrd_27", "thrd_28", "thrd_29", "thrd_30", "thrd_31", "thrd_32", "thrd_33", "thrd_34", "thrd_35", "thrd_36", "thrd_37", "thrd_38", "thrd_39", "thrd_40", "thrd_41", "thrd_42", "thrd_43", "thrd_44", "thrd_45", "thrd_46", "thrd_47", "thrd_48", "thrd_49", "thrd_50", "thrd_51", "thrd_52", "thrd_53", "thrd_54", "thrd_55", "thrd_56", "thrd_57", "thrd_58", "thrd_59", "thrd_60", "thrd_61", "thrd_62", "thrd_63"], "y": ["[SAMPLE] __GI___sched_yield [{} {0}]", "OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]  ", "OpenMP_Implicit_Task", ".TAU application", "[SAMPLE] propagateToZ(MP6x6SF const*, MP6F const*, MP1I const*, MP3F const*, MP6x6SF*, MP6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]", "[SAMPLE] MultHelixPropTranspEndcap(MP6x6F const*, MP6x6F const*, MP6x6SF*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]", "[SAMPLE] MultHelixPropEndcap(MP6x6F const*, MP6x6SF const*, MP6x6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]", "[SAMPLE] __pthread_cond_wait [{} {0}]"], "z": [[13870851, 10745898, 9449820, 10611072, 10339867, 9560014, 7939217, 9495019, 8819710, 9890009, 8928353, 8855166, 8814228, 8511027, 7310486, 12960281, 12515105, 12974773, 12442878, 11900914, 13065179, 8174355, 9088526, 9746109, 11391744, 13039288, 12270518, 12811448, 12768011, 8170967, 7840980, 9275447, 9093919, 9250300, 9055519, 12187601, 13049578, 12764379, 11859575, 12829319, 10266747, 6686102, 9147814, 8158792, 12107717, 7629477, 8874634, 8781462, 12451886, 11520699, 12067723, 12300959, 13593634, 12775188, 13132038, 8393514, 9243210, 7405497, 12233861, 8478287, 13000212, 12654164, 12622193, 13061375], [3743784, 7226249, 7094515, 6731347, 7062465, 8042552, 7955723, 8254101, 8286306, 6858451, 7383036, 8704806, 8437477, 8263651, 7416761, 8171448, 7426964, 6920680, 7304053, 7596495, 7318348, 8267744, 8451146, 8220196, 7054098, 8207575, 7695718, 8050326, 7425582, 7540969, 7710420, 8383524, 7279146, 8516924, 7954412, 7007003, 7021994, 7572587, 7323929, 7575191, 7067616, 7729295, 6877233, 8039057, 6935842, 8176940, 7627072, 7998838, 8192087, 7563023, 7441297, 7136692, 7049528, 6224856, 7528358, 8009741, 7593614, 8221384, 8233139, 7618938, 8188049, 6944180, 8128361, 7532711], [2949747, 8378107, 8041684, 8401100, 7971409, 6991261, 7044474, 6772107, 6745125, 8243501, 6930950, 6661333, 6510869, 7183700, 6926369, 7244495, 8022066, 7650772, 7309673, 6921562, 7315899, 7054899, 6939216, 7215804, 8478562, 7210311, 7189050, 7384461, 8057920, 7456024, 6927172, 6514347, 7400743, 6382771, 7499588, 7672920, 7609497, 6998491, 7324817, 6977102, 8417853, 6877011, 7847113, 6896635, 7757085, 6748747, 7040982, 7482313, 7233407, 7008290, 7141342, 7550571, 7648152, 8531691, 7979653, 7407465, 6603826, 7258351, 7245282, 7093412, 7276359, 7283383, 7362649, 7061253], [2379942, 272, 142, 104, 74, 13745, 13746, 12104, 12073, 4678, 4653, 834, 810, 776, 739, 756, 711, 975, 686, 670, 672, 41952, 28429, 6105, 11535, 11530, 11498, 11480, 11453, 11429, 14279, 14322, 14293, 14271, 14264, 14256, 14230, 14214, 14196, 14175, 14143, 14131, 14094, 14060, 14024, 14000, 13976, 13949, 13952, 13936, 13910, 13894, 13893, 13866, 13843, 13819, 13793, 13768, 13741, 13689, 13619, 13683, 13664, 13650], [255839, 1135347, 1760046, 1354650, 896239, 1454958, 2168977, 1627498, 1618884, 1312313, 2222998, 1798656, 2381364, 1554754, 2715570, 829938, 1080792, 1139907, 1206694, 896685, 709945, 1161374, 1423849, 1905210, 921849, 684960, 838652, 999968, 809831, 1585164, 2645083, 1797014, 1313053, 2659046, 958443, 1338495, 569961, 704897, 1074957, 793281, 1501453, 3765924, 1868632, 2095130, 909555, 1951092, 172 ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333,

# %% [markdown]
# ### Parsing Call Path data
#
# The callpath data is in the `TAU_CALLPATH` group, so we filter our dataframe to give us only the callpaths.
# Further, the calls in the callpath are joined by ` => `, so we split them into a hierarchical index, and construct a tree from the generated multiindexed dataframe. CallPaths class does this for us

# %%
call_paths = CallPaths.from_tau_interval_profile(data, node=0, context=0, thread=1)

# %%
call_paths.to_sunburst_chart(by='time')
# Out:
# <div>
#
#
#             <div id="ae5a414f-42e3-468c-b5fb-2359fc4dbaef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ae5a414f-42e3-468c-b5fb-2359fc4dbaef")) {
#                     Plotly.newPlot(
#                         'ae5a414f-42e3-468c-b5fb-2359fc4dbaef',
#                         [{"labels": [".TAU application", "OpenMP_Thread_Type_ompt_thread_worker", "OpenMP_Implicit_Task", "[SAMPLE] __GI___sched_yield [{} {0}]", "[SAMPLE] __kmp_fork_barrier(int, int) [{} {0}]", "[SAMPLE] __kmp_yield [{} {0}]", "[SAMPLE] __pthread_cond_wait [{} {0}]", "[SAMPLE] __kmp_hardware_timestamp [{} {0}]", "OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]", "[SAMPLE] MultHelixPropEndcap(MP6x6F const*, MP6x6SF const*, MP6x6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]", "[SAMPLE] MultHelixPropTranspEndcap(MP6x6F const*, MP6x6F const*, MP6x6SF*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]", "[SAMPLE] __svml_sincosf8_e9 [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]", "[SAMPLE] propagateToZ(MP6x6SF const*, MP6F const*, MP1I const*, MP3F const*, MP6x6SF*, MP6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]", "[SAMPLE] __pthread_cond_wait [{} {0}]"], "parents": ["", ".TAU application", "OpenMP_Thread_Type_ompt_thread_worker", "OpenMP_Implicit_Task", "OpenMP_Implicit_Task", "OpenMP_Implicit_Task", "OpenMP_Implicit_Task", "OpenMP_Implicit_Task", "OpenMP_Implicit_Task", "OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]", "OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]", "OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]", "OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]", "OpenMP_Thread_Type_ompt_thread_worker"], "type": "sunburst", "values": [272, 150801, 8378107, 10745898, 30139, 372973, 139841, 70590, 7226249, 1231407, 535483, 1413332, 1135347, 5014]}],
#                         {"margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], " ...

# %%
gf = call_paths.to_hatchet()

# %%
print(gf.tree(metric_column="time", expand_name=True))
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.2.0
#
# 272.000 .TAU application
# └─ 150801.000 OpenMP_Thread_Type_ompt_thread_worker
#    ├─ 8378107.000 OpenMP_Implicit_Task
#    │  ├─ 7226249.000 OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]
#    │  │  ├─ 1231407.000 [SAMPLE] MultHelixPropEndcap(MP6x6F const*, MP6x6SF const*, MP6x6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
#    │  │  ├─ 535483.000 [SAMPLE] MultHelixPropTranspEndcap(MP6x6F const*, MP6x6F const*, MP6x6SF*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
#    │  │  ├─ 1413332.000 [SAMPLE] __svml_sincosf8_e9 [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
#    │  │  └─ 1135347.000 [SAMPLE] propagateToZ(MP6x6SF const*, MP6F const*, MP1I const*, MP3F const*, MP6x6SF*, MP6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
#    │  ├─ 10745898.000 [SAMPLE] __GI___sched_yield [{} {0}]
#    │  ├─ 30139.000 [SAMPLE] __kmp_fork_barrier(int, int) [{} {0}]
#    │  ├─ 70590.000 [SAMPLE] __kmp_hardware_timestamp [{} {0}]
#    │  ├─ 372973.000 [SAMPLE] __kmp_yield [{} {0}]
#    │  └─ 139841.000 [SAMPLE] __pthread_cond_wait [{} {0}]
#    └─ 5014.000 [SAMPLE] __pthread_cond_wait [{} {0}]
#
# Legend (Metric: time)
# █ 9671308.20 - 10745898.00
# █ 7522128.60 - 9671308.20
# █ 5372949.00 - 7522128.60
# █ 3223769.40 - 5372949.00
# █ 1074589.80 - 3223769.40
# █ 0.00 - 1074589.80
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
exclusive_per_call_time = call_paths.get_exclusives_per_call_roots()
query = [
    {"groups" : ".*TAU_OPENMP.*"},
    '*'
]

openmp_functions = exclusive_per_call_time.to_hatchet().filter(query, squash=True)
print(openmp_functions.tree(metric_column="time", expand_name=True))
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.2.0
#
# 150801.000 OpenMP_Thread_Type_ompt_thread_worker
# ├─ 83781.070 OpenMP_Implicit_Task
# │  ├─ 72262.490 OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]
# │  │  ├─ 64810.895 [SAMPLE] MultHelixPropEndcap(MP6x6F const*, MP6x6SF const*, MP6x6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
# │  │  ├─ 38248.786 [SAMPLE] MultHelixPropTranspEndcap(MP6x6F const*, MP6x6F const*, MP6x6SF*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
# │  │  ├─ 108717.846 [SAMPLE] __svml_sincosf8_e9 [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
# │  │  └─ 63074.833 [SAMPLE] propagateToZ(MP6x6SF const*, MP6F const*, MP1I const*, MP3F const*, MP6x6SF*, MP6F*) [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0}]
# │  ├─ 11135.646 [SAMPLE] __GI___sched_yield [{} {0}]
# │  ├─ 15069.500 [SAMPLE] __kmp_fork_barrier(int, int) [{} {0}]
# │  ├─ 17647.500 [SAMPLE] __kmp_hardware_timestamp [{} {0}]
# │  ├─ 46621.625 [SAMPLE] __kmp_yield [{} {0}]
# │  └─ 4994.321 [SAMPLE] __pthread_cond_wait [{} {0}]
# └─ 5014.000 [SAMPLE] __pthread_cond_wait [{} {0}]
#
# Legend (Metric: time)
# █ 135720.90 - 150801.00
# █ 105560.70 - 135720.90
# █ 75400.50 - 105560.70
# █ 45240.30 - 75400.50
# █ 15080.10 - 45240.30
# █ 0.00 - 15080.10
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
query = [
    {"time" : "<= 13000.00"},
]

tmp = openmp_functions.filter(query, squash=True)
print(tmp.tree(metric_column="time", expand_name=True))
names = tmp.dataframe['name'].tolist()
regexed_names = "|".join([re.escape(name) for name in names])

# print(regexed_names)
import re
query = [
    {'name': regexed_names}
]

# query
tmp = gf.filter(query, squash=True)
print(tmp.tree(metric_column="time", expand_name=True))
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.2.0
#
# 11135.646 [SAMPLE] __GI___sched_yield [{} {0}]
# 10008.321 [SAMPLE] __pthread_cond_wait [{} {0}]
#
# Legend (Metric: time)
# █ 10022.08 - 11135.65
# █ 7794.95 - 10022.08
# █ 5567.82 - 7794.95
# █ 3340.69 - 5567.82
# █ 1113.56 - 3340.69
# █ 0.00 - 1113.56
#
# name User code    ◀  Only in left graph    ▶  Only in right graph
#
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.2.0
#
# 10745898.000 [SAMPLE] __GI___sched_yield [{} {0}]
# 144855.000 [SAMPLE] __pthread_cond_wait [{} {0}]
#
# Legend (Metric: time)
# █ 9671308.20 - 10745898.00
# █ 7522128.60 - 9671308.20
# █ 5372949.00 - 7522128.60
# █ 3223769.40 - 5372949.00
# █ 1074589.80 - 3223769.40
# █ 0.00 - 1074589.80
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %% [markdown]
# On top of having the `filter` method to prune the callgraphs, we can also directly interact with the `graph` object of a `hatchet.graphframe`. So, for example, we can remove specific nodes from the callgraphs.
# Many times, the deepest functions in a callpath tree (leaves) do most of the work. If we are however interested in knowing the time spent in every call leading to these functions, we can calculate that by removing the leaves of the callpath trees and add up the exclusives of every call leading to the leaves, which would essentially be the inclusive values of the roots of our callpath trees. Hatchet can recalculate the inclusive values each time a graph object changes, through the `squash` function. So when we remove the leaves, by calling `squash()`, hatchet  adds up the exclusive values of each callpath for us.

# %%
# we can directly interact with the graph object of a graphframe
trimmed_gf = gf.copy()
for node in trimmed_gf.graph.traverse(order="post"):
    if len(node.children) == 0: # if doesn't have children it means it's a leaf so we can drop it in the dataframe
        trimmed_gf.dataframe.drop(node, inplace = True) # graph and dataframe are now inconsistant, we need to do squash at the end

trimmed_gf = trimmed_gf.squash() # now the graph and dataframe are consistant
metric = 'time'
print(trimmed_gf.tree(metric_column=metric, expand_name=True)) # showing exclusive time
# Out:
#     __          __       __         __
#    / /_  ____ _/ /______/ /_  ___  / /_
#   / __ \/ __ `/ __/ ___/ __ \/ _ \/ __/
#  / / / / /_/ / /_/ /__/ / / /  __/ /_
# /_/ /_/\__,_/\__/\___/_/ /_/\___/\__/  v1.2.0
#
# 272.000 .TAU application
# └─ 150801.000 OpenMP_Thread_Type_ompt_thread_worker
#    └─ 8378107.000 OpenMP_Implicit_Task
#       └─ 7226249.000 OpenMP_Work_Loop main [{/storage/users/parsab/p2z-tests/bin/propagate_icc_omp} {0, 0}]
#
# Legend (Metric: time)
# █ 7540296.30 - 8378107.00
# █ 5864674.90 - 7540296.30
# █ 4189053.50 - 5864674.90
# █ 2513432.10 - 4189053.50
# █ 837810.70 - 2513432.10
# █ 0.00 - 837810.70
#
# name User code    ◀  Only in left graph    ▶  Only in right graph
